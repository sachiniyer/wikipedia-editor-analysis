# %%
SPARK_MASTER = 'spark://cs303:53725'
SAVE_DIRECTORY = 'scratch/tmv7269/lda'
TARGET_PATH = '/scratch/tmv7269/datasets/wikipedia.en'

# %%
import os
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pyspark

# %%
# setting up spark
from pyspark.sql import SparkSession
import pyspark

spark = SparkSession.builder.master(SPARK_MASTER) \
                            .config('spark.executor.memory', '4G') \
                            .config('spark.driver.memory', '60G') \
                            .config("spark.memory.offHeap.enabled", True) \
                            .config("spark.memory.offHeap.size","16g") \
                            .appName('LDA') \
                            .getOrCreate()
spark.sparkContext.setLogLevel("Off")
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://cs303.hpc.nyu.edu:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://cs303:53725</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>LDA</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from datasets import load_dataset
import datasets
import pandas as pd
import time
from pathlib import Path

datasets.config.DOWNLOADED_DATASETS_PATH = Path(TARGET_PATH + '/data')
datasets.config.HF_DATASETS_CACHE = Path(TARGET_PATH + '/cache')

# LDA parameters, go to max in production
MAX_ITER = 100
CHECKPOINT = 5
K = 100

# %%
# change it to this to use the full 1m dataset
dataset = load_dataset("wikipedia", "20220301.simple")
# dataset = load_dataset("wikipedia", "20220301.simple")
dataset

# %%
sparkDF = spark.createDataFrame(dataset['train'])
sparkDF.columns

# %%
sparkDF.count()

# %%
from pyspark.ml.feature import StopWordsRemover, RegexTokenizer, CountVectorizer
from pyspark.sql.functions import col,udf
from pyspark.sql.types import IntegerType

# %%
tokenizer = RegexTokenizer(inputCol='text',outputCol='words', pattern = '[^a-zA-Z]')
tokenized_df = tokenizer.transform(sparkDF).drop('text')
tokenized_df.head()

# %%
remover = StopWordsRemover(inputCol="words", outputCol="filtered")
removed_df = remover.transform(tokenized_df).drop('words')
removed_df.head()

# %%
cv = CountVectorizer(inputCol="filtered", outputCol="features", minDF=2.0).fit(removed_df)

lda_count = cv.transform(removed_df).drop('filtered')
lda_count.head()
# Out:
# Row(id='1', title='April', url='https://simple.wikipedia.org/wiki/April', features=SparseVector(221737, {0: 5.0, 1: 1.0, 2: 7.0, 3: 3.0, 4: 17.0, 5: 1.0, 6: 10.0, 7: 3.0, 8: 13.0, 9: 8.0, 12: 3.0, 13: 1.0, 14: 1.0, 17: 13.0, 18: 2.0, 19: 1.0, 22: 1.0, 25: 10.0, 26: 6.0, 27: 1.0, 32: 7.0, 34: 1.0, 35: 4.0, 37: 4.0, 38: 5.0, 40: 1.0, 41: 1.0, 42: 20.0, 44: 7.0, 46: 3.0, 49: 4.0, 50: 5.0, 55: 25.0, 56: 1.0, 59: 1.0, 60: 6.0, 61: 13.0, 62: 1.0, 65: 1.0, 66: 1.0, 67: 4.0, 71: 3.0, 72: 3.0, 76: 3.0, 77: 5.0, 78: 208.0, 81: 1.0, 82: 3.0, 85: 3.0, 86: 1.0, 90: 1.0, 93: 2.0, 94: 2.0, 96: 1.0, 97: 1.0, 103: 2.0, 106: 1.0, 109: 96.0, 111: 10.0, 117: 5.0, 120: 1.0, 123: 1.0, 126: 2.0, 129: 2.0, 140: 1.0, 142: 5.0, 147: 4.0, 152: 3.0, 153: 5.0, 154: 1.0, 155: 1.0, 156: 1.0, 158: 3.0, 159: 2.0, 160: 1.0, 161: 2.0, 162: 1.0, 170: 1.0, 174: 4.0, 176: 2.0, 181: 5.0, 183: 2.0, 184: 4.0, 186: 2.0, 187: 2.0, 188: 1.0, 192: 1.0, 194: 1.0, 198: 1.0, 199: 1.0, 200: 4.0, 203: 1.0, 204: 1.0, 205: 2.0, 206: 3.0, 207: 1.0, 210: 1.0, 214: 1.0, 215: 2.0, 218: 1.0, 223: 2.0, 228: 1.0, 240: 1.0, 243: 2.0, 244: 1.0, 245: 1.0, 246: 2.0, 248: 1.0, 249: 1.0, 250: 2.0, 251: 1.0, 252: 1.0, 253: 2.0, 255: 2.0, 258: 1.0, 259: 4.0, 262: 3.0, 265: 1.0, 270: 4.0, 273: 1.0, 274: 1.0, 277: 1.0, 280: 1.0, 282: 5.0, 289: 4.0, 290: 2.0, 293: 7.0, 294: 2.0, 295: 2.0, 296: 1.0, 300: 4.0, 301: 1.0, 303: 3.0, 307: 1.0, 316: 1.0, 324: 1.0, 331: 1.0, 333: 2.0, 334: 1.0, 336: 5.0, 337: 1.0, 341: 1.0, 346: 5.0, 348: 1.0, 349: 1.0, 351: 6.0, 357: 3.0, 358: 1.0, 359: 1.0, 360: 3.0, 364: 4.0, 365: 1.0, 366: 1.0, 368: 2.0, 370: 1.0, 371: 1.0, 374: 1.0, 379: 1.0, 384: 1.0, 392: 2.0, 393: 5.0, 395: 1.0, 396: 1.0, 397: 1.0, 398: 1.0, 399: 2.0, 411: 1.0, 413: 1.0, 417: 2.0, 418: 2.0, 422: 2.0, 425: 1.0, 426: 1.0, 431: 1.0, 443: 2.0, 445: 3.0, 449: 1.0, 450: 1.0, 453: 2.0, 454: 1.0, 462: 2.0, 466: 1.0, 468: 1.0, 473: 1.0, 477: 1.0, 480: 3.0, 481: 1.0, 490: 1.0, 497: 1.0, 500: 2.0, 506: 4.0, 514: 2.0, 515: 1.0, 522: 1.0, 525: 3.0, 527: 1.0, 535: 6.0, 536: 1.0, 540: 2.0, 549: 1.0, 550: 2.0, 551: 1.0, 554: 1.0, 555: 2.0, 560: 1.0, 561: 1.0, 564: 2.0, 572: 1.0, 573: 1.0, 575: 4.0, 576: 1.0, 579: 1.0, 584: 1.0, 591: 1.0, 601: 1.0, 603: 1.0, 604: 2.0, 605: 5.0, 624: 13.0, 628: 2.0, 635: 1.0, 642: 2.0, 645: 1.0, 646: 1.0, 654: 4.0, 659: 3.0, 663: 2.0, 665: 5.0, 666: 1.0, 676: 1.0, 684: 2.0, 688: 2.0, 689: 12.0, 691: 2.0, 700: 2.0, 702: 1.0, 713: 1.0, 723: 2.0, 726: 1.0, 727: 2.0, 736: 2.0, 741: 2.0, 744: 1.0, 748: 1.0, 753: 1.0, 754: 1.0, 762: 3.0, 763: 1.0, 764: 1.0, 782: 1.0, 785: 3.0, 787: 5.0, 793: 1.0, 798: 1.0, 799: 2.0, 811: 1.0, 815: 2.0, 824: 2.0, 829: 9.0, 831: 2.0, 854: 1.0, 857: 2.0, 865: 8.0, 870: 1.0, 871: 1.0, 886: 4.0, 890: 1.0, 903: 1.0, 906: 3.0, 911: 2.0, 912: 1.0, 916: 1.0, 919: 1.0, 930: 1.0, 940: 2.0, 941: 1.0, 950: 1.0, 958: 2.0, 967: 1.0, 968: 1.0, 973: 1.0, 985: 1.0, 987: 3.0, 990: 1.0, 992: 2.0, 993: 1.0, 999: 1.0, 1012: 1.0, 1021: 2.0, 1067: 2.0, 1070: 1.0, 1073: 1.0, 1077: 1.0, 1088: 2.0, 1090: 1.0, 1094: 1.0, 1117: 1.0, 1147: 1.0, 1160: 1.0, 1167: 1.0, 1169: 1.0, 1171: 1.0, 1179: 15.0, 1186: 1.0, 1200: 1.0, 1202: 1.0, 1203: 1.0, 1231: 1.0, 1269: 1.0, 1292: 2.0, 1305: 1.0, 1309: 1.0, 1315: 5.0, 1333: 3.0, 1360: 1.0, 1363: 4.0, 1365: 1.0, 1392: 1.0, 1394: 4.0, 1395: 1.0, 1403: 2.0, 1413: 1.0, 1424: 2.0, 1426: 2.0, 1443: 1.0, 1448: 1.0, 1449: 4.0, 1454: 1.0, 1455: 1.0, 1462: 1.0, 1472: 1.0, 1476: 2.0, 1494: 1.0, 1496: 3.0, 1502: 1.0, 1508: 1.0, 1512: 2.0, 1526: 1.0, 1531: 1.0, 1545: 1.0, 1554: 1.0, 1582: 1.0, 1585: 2.0, 1603: 3.0, 1611: 6.0, 1615: 4.0, 1617: 2.0, 1629: 1.0, 1634: 2.0, 1639: 1.0, 1656: 1.0, 1665: 1.0, 1668: 1.0, 1670: 2.0, 1673: 1.0, 1679: 1.0, 1685: 1.0, 1694: 1.0, 1720: 1.0, 1734: 1.0, 1761: 1.0, 1808: 1.0, 1837: 1.0, 1847: 1.0, 1869: 3.0, 1870: 2.0, 1871: 1.0, 1875: 1.0, 1876: 1.0, 1890: 2.0, 1921: 2.0, 1928: 1.0, 1940: 1.0, 1968: 1.0, 2010: 1.0, 2020: 1.0, 2033: 1.0, 2048: 1.0, 2077: 1.0, 2104: 1.0, 2118: 1.0, 2119: 4.0, 2139: 4.0, 2151: 1.0, 2155: 1. ...

# %%
from pyspark.ml.clustering import LDA

# create LDA with K topics

start = time.time()
lda = LDA(k=K, seed=1, optimizer="em", maxIter=MAX_ITER, checkpointInterval=CHECKPOINT)
model = lda.fit(lda_count)
end = time.time()

print(f"Time elapsed: {end-start:.2f} seconds")
# Out:
# Time elapsed: 678.89 seconds

# %%
topicIndices = model.describeTopics(maxTermsPerTopic = 5)
vocabList = cv.vocabulary

for row in topicIndices.collect():
    print(f"Topic {row.topic + 1}: ")
    for topic, weight in zip(row.termIndices, row.termWeights):
        print(f"{vocabList[topic]} {weight:.2E}")
    print()
# Out:
# Topic 1:
# south 1.38E-01
# australia 7.48E-02
# australian 5.47E-02
# africa 4.27E-02
# african 4.11E-02
#
# Topic 2:
# january 2.01E-01
# president 1.43E-01
# former 1.12E-01
# office 4.85E-02
# head 3.85E-02
#
# Topic 3:
# california 8.23E-02
# park 6.91E-02
# o 6.77E-02
# san 5.62E-02
# brazilian 2.92E-02
#
# Topic 4:
# may 3.38E-01
# radio 6.07E-02
# news 4.32E-02
# bbc 2.57E-02
# host 2.46E-02
#
# Topic 5:
# people 8.27E-01
# lived 7.02E-02
# live 4.12E-02
# million 2.44E-02
# oldest 6.86E-03
#
# Topic 6:
# series 1.22E-01
# television 9.81E-02
# show 6.04E-02
# tv 3.19E-02
# season 2.54E-02
#
# Topic 7:
# church 8.75E-02
# switzerland 6.50E-02
# municipality 6.47E-02
# municipalities 6.36E-02
# canton 4.78E-02
#
# Topic 8:
# north 1.34E-01
# local 3.31E-02
# asia 2.91E-02
# areas 2.86E-02
# government 2.69E-02
#
# Topic 9:
# called 8.39E-02
# made 8.02E-02
# like 6.09E-02
# many 5.92E-02
# used 4.27E-02
#
# Topic 10:
# world 2.79E-01
# championship 4.59E-02
# times 3.86E-02
# time 3.79E-02
# one 3.44E-02
#
# Topic 11:
# animated 1.78E-02
# disney 1.75E-02
# additional 9.99E-03
# cat 9.98E-03
# voice 9.65E-03
#
# Topic 12:
# species 2.97E-02
# found 1.08E-02
# animals 1.06E-02
# birds 1.01E-02
# fish 9.44E-03
#
# Topic 13:
# national 1.37E-01
# establishments 1.27E-01
# related 1.26E-01
# since 1.02E-01
# pages 9.44E-02
#
# Topic 14:
# used 4.88E-02
# often 4.16E-02
# different 3.33E-02
# example 2.85E-02
# usually 2.79E-02
#
# Topic 15:
# king 5.09E-02
# ii 2.62E-02
# ireland 1.96E-02
# prince 1.95E-02
# son 1.83E-02
#
# Topic 16:
# county 2.37E-01
# u 7.22E-02
# state 5.05E-02
# illinois 3.97E-02
# seat 3.93E-02
#
# Topic 17:
# football 7.11E-02
# league 6.62E-02
# rowspan 6.45E-02
# club 4.48E-02
# colspan 3.96E-02
#
# Topic 18:
# deaths 2.46E-01
# died 1.56E-01
# age 8.57E-02
# births 8.42E-02
# cancer 4.51E-02
#
# Topic 19:
# party 4.41E-02
# election 4.35E-02
# elected 2.96E-02
# members 2.39E-02
# parliament 2.36E-02
#
# Topic 20:
# france 1.03E-01
# department 9.52E-02
# region 8.31E-02
# commune 8.03E-02
# communes 7.30E-02
#
# Topic 21:
# known 2.73E-01
# also 1.97E-01
# part 1.86E-01
# major 5.88E-02
# well 5.05E-02
#
# Topic 22:
# line 4.88E-02
# station 4.38E-02
# road 3.07E-02
# bridge 2.39E-02
# railway 2.37E-02
#
# Topic 23:
# america 9.93E-02
# long 9.28E-02
# female 4.53E-02
# lives 4.05E-02
# big 4.05E-02
#
# Topic 24:
# game 9.05E-02
# games 6.71E-02
# video 5.36E-02
# player 2.04E-02
# released 1.65E-02
#
# Topic 25:
# computer 2.54E-02
# system 1.95E-02
# data 1.61E-02
# systems 1.26E-02
# code 1.12E-02
#
# Topic 26:
# italian 7.49E-02
# italy 5.62E-02
# roman 3.16E-02
# catholic 3.08E-02
# pope 2.35E-02
#
# Topic 27:
# white 3.72E-02
# black 3.34E-02
# red 3.23E-02
# color 2.16E-02
# food 2.13E-02
#
# Topic 28:
# children 4.10E-02
# virginia 3.58E-02
# married 3.35E-02
# james 3.18E-02
# pennsylvania 3.05E-02
#
# Topic 29:
# became 2.49E-01
# country 1.28E-01
# first 5.52E-02
# moved 5.37E-02
# started 2.69E-02
#
# Topic 30:
# many 4.57E-02
# history 3.47E-02
# century 2.79E-02
# modern 2.53E-02
# important 2.31E-02
#
# Topic 31:
# number 6.18E-02
# x 2.29E-02
# numbers 2.14E-02
# one 1.39E-02
# two 1.18E-02
#
# Topic 32:
# district 1.54E-01
# province 9.87E-02
# capital 7.87E-02
# municipality 5.83E-02
# settlements 3.73E-02
#
# Topic 33:
# university 1.48E-01
# college 4.04E-02
# research 2.62E-02
# science 2.42E-02
# studied 2.29E-02
#
# Topic 34:
# best 1.29E-01
# award 9.94E-02
# awards 5.44E-02
# won 4.07E-02
# academy 3.33E-02
#
# Topic 35:
# energy 2.50E-02
# light 2.23E-02
# power 1.66E-02
# nuclear 1.25E-02
# mass 1.11E-02
#
# Topic 36:
# n 5.93E-02
# de 4.13E-02
# spanish 3.70E-02
# la 2.85E-02
# spain 2.61E-02
#
# Topic 37:
# group 1.41E-01
# m 1.17E-01
# style 4.09E-02
# center 3.58E-02
# korea 3.11E-02
#
# Topic 38:
# character 2.37E-02
# action 2.24E-02
# characters 1.85E-02
# cast 1.54E-02
# fictional 1.48E-02
#
# Topic 39:
# india 4.95E-02
# indian 3.85E-02
# pakistan 2.90E-02
# al 2.68E-02
# iran 1.34E-02
#
# Topic 40:
# art 6.43E-02
# artists 2.47E-02
# artist 2.37E-02
# works 2.24E-02
# arts 2.05E-02
#
# Topic 41:
# th 1.49E-01
# japan 8.03E-02
# japanese 7.49E-02
# century 5.31E-02
# prefecture 2.11E-02
#
# Topic 42:
# god 1.99E-02
# religion 1.90E-02
# temple 1.78E-02
# religious 1.39E-02
# mythology 1.29E-02
#
# Topic 43:
# island 5.65E-02
# islands 3.04E-02
# tropical 2.57E-02
# storm 2.42E-02
# hurricane 2.29E-02
#
# Topic 44:
# french 6.38E-02
# saint 4.29E-02
# de 4.24E-02
# france 2.86E-02
# le 2.45E-02
#
# Topic 45:
# german 8.63E-02
# germany 7.69E-02
# austria 1.90E-02
# austrian 1.85E-02
# berlin 1.64E-02
#
# Topic 46:
# second 7.35E-02
# third 4.30E-02
# final 2.87E-02
# round 2.20E-02
# first 2.08E-02
#
# Topic 47:
# john 3.13E-02
# david 1.87E-02
# michael 1.60E-02
# paul 1.35E-02
# peter 9.00E-03
#
# Topic 48:
# earth 3.60E-02
# space 2.78E-02
# star 2.44E-02
# sun 2.37E-02
# moon 1.66E-02
#
# Topic 49:
# river 1.01E-01
# km 2.95E-02
# lake 2.60E-02
# area 2.40E-02
# mountain 1.80E-02
#
# Topic 50:
# music 6.64E-02
# opera 1.88E-02
# composer 1.33E-02
# composers 1.25E-02
# orchestra 1.24E-02
#
# Topic 51:
# home 7.21E-02
# famous 5.27E-02
# popular 4.85E-02
# around 2.19E-02
# also 1.73E-02
#
# Topic 52:
# kingdom 1.39E-01
# family 1.29E-01
# king 3.14E-02
# mainly 2.77E-02
# romania 2.05E-02
#
# Topic 53:
# refer 2.19E-02
# true 1.73E-02
# philosophy 1.72E-02
# see 1.70E-02
# idea 1.56E-02
#
# Topic 54:
# built 3.67E-02
# building 3.28E-02
# buildings 2.79E-02
# museum 2.05E-02
# castle 1.80E-02
#
# Topic 55:
# member 1.03E-01
# politicians 8.71E-02
# politician 6.15E-02
# us 5.68E-02
# party 4.93E-02
#
# Topic 56:
# american 3.24E-02
# politician 2.00E-02
# actor 1.30E-02
# player 1.20E-02
# cancer 9.81E-03
#
# Topic 57:
# russian 5.09E-02
# union 4.68E-02
# soviet 3.91E-02
# russia 3.64E-02
# polish 2.45E-02
#
# Topic 58:
# b 5.56E-02
# d 4.36E-02
# american 4.23E-02
# actor 1.12E-02
# politician 1.04E-02
#
# Topic 59:
# players 4.72E-02
# hockey 3.89E-02
# canadian 3.77E-02
# chicago 3.55E-02
# canada 3.36E-02
#
# Topic 60:
# websites 4.02E-01
# town 1.38E-01
# official 1.37E-01
# website 1.18E-01
# towns 5.66E-02
#
# Topic 61:
# com 4.19E-02
# page 2.32E-02
# version 2.17E-02
# web 2.11E-02
# internet 2.11E-02
#
# Topic 62:
# born 4.05E-01
# births 2.45E-01
# living 2.18E-01
# career 5.50E-02
# retired 1.28E-02
#
# Topic 63:
# school 1.03E-01
# high 5.93E-02
# public 4.69E-02
# education 3.04E-02
# schools 2.39E-02
#
# Topic 64:
# said 2.98E-02
# time 1.63E-02
# good 1.50E-02
# get 1.41E-02
# back 1.38E-02
#
# Topic 65:
# law 3.29E-02
# court 2.50E-02
# rights 2.37E-02
# police 2.00E-02
# act 1.19E-02
#
# Topic 66:
# texas 7.91E-02
# florida 5.47E-02
# sports 4.02E-02
# american 3.85E-02
# association 3.29E-02
#
# Topic 67:
# title 4.07E-02
# event 2.85E-02
# wwe 2.81E-02
# match 2.62E-02
# wrestling 2.40E-02
#
# Topic 68:
# c 1.13E-01
# d 1.00E-01
# e 9.37E-02
# r 6.73E-02
# b 5.74E-02
#
# Topic 69:
# k 4.31E-02
# mostly 3.17E-02
# include 2.19E-02
# norway 2.04E-02
# wood 1.89E-02
#
# Topic 70:
# name 8.79E-02
# language 7.38E-02
# china 4.71E-02
# chinese 3.84E-02
# languages 3.48E-02
#
# Topic 71:
# american 6.34E-02
# prize 5.49E-02
# scientists 3.37E-02
# jewish 3.01E-02
# nobel 2.96E-02
#
# Topic 72:
# book 5.63E-02
# books 4.86E-02
# writers 4.11E-02
# published 3.41E-02
# wrote 2.81E-02
#
# Topic 73:
# united 4.01E-01
# states 3.56E-01
# washington 4.01E-02
# u 3.16E-02
# american 2.56E-02
#
# Topic 74:
# american 2.13E-01
# actors 1.42E-01
# movie 6.84E-02
# television 5.21E-02
# actor 3.50E-02
#
# Topic 75:
# war 8.13E-02
# army 3.04E-02
# military 2.94E-02
# battle 1.87E-02
# ii 1.59E-02
#
# Topic 76:
# mother 2.44E-02
# father 2.41E-02
# love 1.49E-02
# brother 1.41E-02
# sister 1.15E-02
#
# Topic 77:
# company 7.50E-02
# founded 4.53E-02
# companies 3.08E-02
# based 2.74E-02
# business 2.63E-02
#
# Topic 78:
# life 1.26E-01
# death 9.51E-02
# named 8.54E-02
# also 7.82E-02
# man 7.18E-02
#
# Topic 79:
# later 5.45E-02
# began 3.25E-02
# early 2.76E-02
# several 1.76E-02
# however 1.63E-02
#
# Topic 80:
# air 5.71E-02
# airport 2.95E-02
# fire 2.73E-02
# aircraft 2.38E-02
# flight 2.33E-02
#
# Topic 81:
# references 9.42E-01
# tour 5.95E-03
# overall 4.16E-03
# classification 3.10E-03
# giro 1.20E-03
#
# Topic 82:
# human 1.57E-02
# cell 1.20E-02
# cells 9.30E-03
# dna 8.07E-03
# biology 6.42E-03
#
# Topic 83:
# car 3.13E-02
# race 2.64E-02
# class 2.18E-02
# grand 1.90E-02
# one 1.88E-02
#
# Topic 84:
# british 1.74E-01
# st 1.03E-01
# london 8.75E-02
# order 4.65E-02
# uk 4.12E-02
#
# Topic 85:
# first 1.50E-01
# year 7.78E-02
# two 7.02E-02
# one 6.94E-02
# three 6.82E-02
#
# Topic 86:
# empire 3.40E-02
# bc 2.78E-02
# greek 2.58E-02
# roman 2.52E-02
# ancient 2.22E-02
#
# Topic 87:
# city 1.01E-01
# state 8.43E-02
# cities 8.43E-02
# population 8.38E-02
# area 6.17E-02
#
# Topic 88:
# kansas 4.92E-02
# massachusetts 3.23E-02
# missouri 2.99E-02
# native 2.35E-02
# land 1.77E-02
#
# Topic 89:
# new 4.24E-01
# city 2.41E-01
# york 1.56E-01
# jersey 3.30E-02
# manhattan 9.25E-03
#
# Topic 90:
# countries 5.05E-02
# international 4.43E-02
# money 1.80E-02
# bank 1.73E-02
# nations 1.72E-02
#
# Topic 91:
# english 1.75E-01
# england 8.75E-02
# west 7.38E-02
# village 5.05E-02
# east 2.29E-02
#
# Topic 92:
# side 2.58E-02
# back 1.50E-02
# move 1.45E-02
# hand 1.41E-02
# ball 1.32E-02
#
# Topic 93:
# march 1.06E-01
# july 9.91E-02
# october 9.76E-02
# june 9.75E-02
# september 9.59E-02
#
# Topic 94:
# women 8.45E-02
# summer 5.27E-02
# gold 3.67E-02
# olympics 3.44E-02
# olympic 3.17E-02
#
# Topic 95:
# movies 2.13E-01
# movie 9.02E-02
# american 5.01E-02
# directed 4.94E-02
# drama 4.85E-02
#
# Topic 96:
# body 1.63E-02
# blood 1.53E-02
# person 1.12E-02
# cause 1.05E-02
# brain 9.47E-03
#
# Topic 97:
# water 4.40E-02
# chemical 1.84E-02
# used 1.78E-02
# gas 1.11E-02
# iron 1.05E-02
#
# Topic 98:
# minister 6.20E-02
# government 5.18E-02
# prime 4.91E-02
# political 4.66E-02
# dutch 3.28E-02
#
# Topic 99:
# album 3.70E-02
# song 3.24E-02
# band 2.78E-02
# music 2.62E-02
# released 2.47E-02
#
# Topic 100:
# god 2.51E-02
# christian 2.00E-02
# jesus 1.56E-02
# bible 1.20E-02
# believe 8.70E-03

# %%
model.write().overwrite().save('/scratch/tmv7269/lda')

# %%
model.vocabSize()
# Out:
# 221737

# %%
model.logPerplexity(lda_count)

# %%
model.logLikelihood(lda_count)
