# %%
import time
import os, gc
import pyspark
import pandas as pd
from itertools import islice
from pyspark.sql.types import *
from pyspark import SparkContext
from pyspark.sql import SparkSession
from pyspark.sql import Row
from lxml import etree as ET
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk/jre"
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.12:0.12.0 pyspark-shell' 
num_of_th = 512; repartition_size = num_of_th*16; chunk_size = 1000000

# %%
sc = SparkContext(master = "local[*]") \
        .getOrCreate()
spark = SparkSession(sc)
udf_registration = pyspark.sql.udf.UDFRegistration(spark)

spark
# Out:
# 23/04/13 05:54:41 WARN Utils: Your hostname, siyer resolves to a loopback address: 127.0.1.1; using 10.18.157.43 instead (on interface wlp166s0)
# 23/04/13 05:54:41 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# :: loading settings :: url = jar:file:/home/siyer/.pyenv/versions/3.10.10/envs/mmds/lib/python3.10/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/siyer/.ivy2/cache
# The jars for the packages stored in: /home/siyer/.ivy2/jars
# com.databricks#spark-xml_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-f20b3fee-8e17-4f7d-aab1-88d8be831c72;1.0
# 	confs: [default]
# 	found com.databricks#spark-xml_2.12;0.12.0 in central
# 	found commons-io#commons-io;2.8.0 in central
# 	found org.glassfish.jaxb#txw2;2.3.3 in central
# 	found org.apache.ws.xmlschema#xmlschema-core;2.2.5 in central
# ...

# %%
file_rdd = spark.read.text("./data/dump1.xml", wholetext=False)

file_rdd.take(10)

file_chunk = file_rdd.take(chunk_size)

# %%
myRDD = sc.parallelize(file_chunk)

def count_in_a_partition(idx, iterator):
    count = 0
    for _ in iterator:
        count += 1
    return idx,count

count_list = myRDD.mapPartitionsWithIndex(count_in_a_partition).collect()
# Out:
# 23/04/13 05:54:52 WARN TaskSetManager: Stage 3 contains a task of very large size (8039 KiB). The maximum recommended task size is 1000 KiB.

# %%
c = {
    "PAGE_TAG": "page",
    "TITLE_TAG": "title",
    "TEXT_TAG": "text",
    "IP_TAG": "ip",
    "USER_TAG": "username",
}


schema = StructType([
    StructField("title", StringType(), True),
    StructField("text", StringType(), True),
    StructField("ip", ArrayType(StringType()), True),
    StructField("user", ArrayType(StringType()), True)
])

# Create an empty DataFrame with the specified schema

entry_blank = {
    "title": "",
    "text": "",
    "ip": [],
    "user": []
}

entry = entry_blank

# %%
c["USER_TAG"] in "username:>"
# Out:
# True

# %%
def get_values(i,x,event_array):
    try:
        root = ET.fromstring(x[0])
        for i in root.iter():
            print(i.tag)
            if (c["PAGE_TAG"] in i.tag):
                event_array.append((entry["title"], 
                             entry["text"], 
                             entry["ip"], 
                             entry["user"]
                                   ))
                print(entry)
                entry = entry_blank

            elif (c["TITLE_TAG"] in i.tag):
                entry["title"] = i.text
                print("inside")
            elif (c["TEXT_TAG"] in i.tag):
                entry["text"] = i.text
                print("inside")
            elif (c["IP_TAG"] in i.tag):
                entry["ip"].append(i.text)
                print("inside")
            elif (c["USER_TAG"] in i.tag):
                entry["user"].append(i.text)
                print("inside")

    except:pass
    gc.collect()
    return event_array

# %%
udf_registration.register(name="get_values", f=get_values, returnType=ArrayType(schema))
# Out:
# <function __main__.get_values(i, x, event_array)>

# %%
for idx_,count in enumerate(count_list):
    chunk = myRDD.mapPartitionsWithIndex(lambda i, it: islice(it, 0, count) if i == idx_ else []).collect()
    myRDD_ = sc.parallelize(chunk)  
    myRDD_ = myRDD_.repartition(repartition_size)
    
    event_array = []
    elems = sc.runJob(myRDD_, lambda part: [get_values(i,x,event_array) for i,x in enumerate(part)])
    print(elems)
    print(event_array)
# Out:
# 23/04/13 05:56:57 WARN TaskSetManager: Stage 4 contains a task of very large size (8039 KiB). The maximum recommended task size is 1000 KiB.
# []
# []
# 23/04/13 05:58:13 WARN TaskSetManager: Stage 7 contains a task of very large size (8039 KiB). The maximum recommended task size is 1000 KiB.
# model
# format
# timestamp>                                                      (3 + 16) / 8192]
# username
# id
# id
# modele 9:>                                                      (8 + 16) / 8192]
# parentid
# format
# timestamp
# username
# id
# model
# format
# sha1
# sha1ge 9:>                                                     (12 + 16) / 8192]
# id
# parentid
# sha1
# idtage 9:>                                                     (18 + 16) / 8192]
# parentid
# timestamp
# username
# minor
# id
# comment
# model
# format
# sha1ge 9:>                                                     (21 + 16) / 8192]
# ...

# %%
from pyspark.ml.linalg import Vectors, SparseVector
from pyspark.ml.clustering import LDA

lda = LDA(k=100, seed=1, optimizer="em")
lda.setMaxIter(5)

lda.getMaxIter()

lda.clear(lda.maxIter)
model = lda.fit(df)
model.setSeed(1)

model.getTopicDistributionCol()

model.isDistributed()

localModel = model.toLocal()
localModel.isDistributed()

model.vocabSize()

model.describeTopics().show()

model.topicsMatrix()
