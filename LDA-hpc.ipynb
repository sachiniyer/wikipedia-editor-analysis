# %%
SPARK_MASTER = 'spark://cm027:52337'
SAVE_DIRECTORY = 'scratch/tmv7269/lda'

# %%
# HPC cluster's pyspark is 3.1.2
# !pip install --upgrade datasets apache-beam pyspark==3.1.2 findspark

# %%
import os
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pyspark

# %%
current_context = SparkContext.getOrCreate()
current_context.stop()

# %%
conf = SparkConf().setAppName("LDA") \
                  .setMaster(SPARK_MASTER)


sc = SparkContext(conf=conf)

spark = SparkSession(sc)

udf_registration = pyspark.sql.udf.UDFRegistration(spark)

spark

# %%
from datasets import load_dataset
import pandas as pd
import time

# LDA parameters, go to max in production
MAX_ITER = 100
CHECKPOINT = 5
K = 100

# %%
# change it to this to use the full 1m dataset
# dataset = load_dataset("wikipedia", "20220301.en")
dataset = load_dataset("wikipedia", "20220301.simple")
dataset
# Out:
# WARNING:datasets.builder:Found cached dataset wikipedia (/home/tmv7269/.cache/huggingface/datasets/wikipedia/20220301.simple/2.0.0/aa542ed919df55cc5d3347f42dd4521d05ca68751f50dbc32bae2a7f1e167559)
#   0%|          | 0/1 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'url', 'title', 'text'],
#         num_rows: 205328
#     })
# })

# %%
sparkDF = spark.createDataFrame(dataset['train'])
sparkDF.columns
# Out:
# ['id', 'text', 'title', 'url']

# %%
sparkDF.count()
# Out:
# 23/04/29 18:18:15 WARN TaskSetManager: Stage 0 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# 205328

# %%
from pyspark.ml.feature import StopWordsRemover, RegexTokenizer, CountVectorizer
from pyspark.sql.functions import col,udf
from pyspark.sql.types import IntegerType

# %%
tokenizer = RegexTokenizer(inputCol='text',outputCol='words', pattern = '[^a-zA-Z]')
tokenized_df = tokenizer.transform(sparkDF).drop('text')
tokenized_df.head()
# Out:
# 23/04/29 18:18:42 WARN TaskSetManager: Stage 2 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# Row(id='1', title='April', url='https://simple.wikipedia.org/wiki/April', words=['april', 'is', 'the', 'fourth', 'month', 'of', 'the', 'year', 'in', 'the', 'julian', 'and', 'gregorian', 'calendars', 'and', 'comes', 'between', 'march', 'and', 'may', 'it', 'is', 'one', 'of', 'four', 'months', 'to', 'have', 'days', 'april', 'always', 'begins', 'on', 'the', 'same', 'day', 'of', 'week', 'as', 'july', 'and', 'additionally', 'january', 'in', 'leap', 'years', 'april', 'always', 'ends', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'december', 'april', 's', 'flowers', 'are', 'the', 'sweet', 'pea', 'and', 'daisy', 'its', 'birthstone', 'is', 'the', 'diamond', 'the', 'meaning', 'of', 'the', 'diamond', 'is', 'innocence', 'the', 'month', 'april', 'comes', 'between', 'march', 'and', 'may', 'making', 'it', 'the', 'fourth', 'month', 'of', 'the', 'year', 'it', 'also', 'comes', 'first', 'in', 'the', 'year', 'out', 'of', 'the', 'four', 'months', 'that', 'have', 'days', 'as', 'june', 'september', 'and', 'november', 'are', 'later', 'in', 'the', 'year', 'april', 'begins', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'july', 'every', 'year', 'and', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'january', 'in', 'leap', 'years', 'april', 'ends', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'december', 'every', 'year', 'as', 'each', 'other', 's', 'last', 'days', 'are', 'exactly', 'weeks', 'days', 'apart', 'in', 'common', 'years', 'april', 'starts', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'october', 'of', 'the', 'previous', 'year', 'and', 'in', 'leap', 'years', 'may', 'of', 'the', 'previous', 'year', 'in', 'common', 'years', 'april', 'finishes', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'july', 'of', 'the', 'previous', 'year', 'and', 'in', 'leap', 'years', 'february', 'and', 'october', 'of', 'the', 'previous', 'year', 'in', 'common', 'years', 'immediately', 'after', 'other', 'common', 'years', 'april', 'starts', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'january', 'of', 'the', 'previous', 'year', 'and', 'in', 'leap', 'years', 'and', 'years', 'immediately', 'after', 'that', 'april', 'finishes', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'january', 'of', 'the', 'previous', 'year', 'in', 'years', 'immediately', 'before', 'common', 'years', 'april', 'starts', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'september', 'and', 'december', 'of', 'the', 'following', 'year', 'and', 'in', 'years', 'immediately', 'before', 'leap', 'years', 'june', 'of', 'the', 'following', 'year', 'in', 'years', 'immediately', 'before', 'common', 'years', 'april', 'finishes', 'on', 'the', 'same', 'day', 'of', 'the', 'week', 'as', 'september', 'of', 'the', 'following', 'year', 'and', 'in', 'years', 'immediately', 'before', 'leap', 'years', 'march', 'and', 'june', 'of', 'the', 'following', 'year', 'april', 'is', 'a', 'spring', 'month', 'in', 'the', 'northern', 'hemisphere', 'and', 'an', 'autumn', 'fall', 'month', 'in', 'the', 'southern', 'hemisphere', 'in', 'each', 'hemisphere', 'it', 'is', 'the', 'seasonal', 'equivalent', 'of', 'october', 'in', 'the', 'other', 'it', 'is', 'unclear', 'as', 'to', 'where', 'april', 'got', 'its', 'name', 'a', 'common', 'theory', 'is', 'that', 'it', 'comes', 'from', 'the', 'latin', 'word', 'aperire', 'meaning', 'to', 'open', 'referring', 'to', 'flowers', 'opening', 'in', 'spring', 'another', 'theory', 'is', 'that', 'the', 'name', 'could', 'come', 'from', 'aphrodite', 'the', 'greek', 'goddess', 'of', 'love', 'it', 'was', 'originally', 'the', 'second', 'month', 'in', 'the', 'old', 'roman', 'calendar', 'before', 'the', 'start', 'of', 'the', 'new', 'year', 'was', 'put', 'to', 'january', 'quite', 'a', 'few', 'festivals', 'are', 'held', 'in', 'this', 'month', 'in', 'many', 'southeast', 'asian', 'cultures', 'new', 'year', 'is', 'celebrated', 'in', 'this', 'month', 'including', 'songkran', 'in', 'western', 'christianity', 'easter', 'can', 'be', 'celebrated', 'on',  ...

# %%
remover = StopWordsRemover(inputCol="words", outputCol="filtered")
removed_df = remover.transform(tokenized_df).drop('words')
removed_df.head()
# Out:
# 23/04/29 18:18:58 WARN TaskSetManager: Stage 3 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# Row(id='1', title='April', url='https://simple.wikipedia.org/wiki/April', filtered=['april', 'fourth', 'month', 'year', 'julian', 'gregorian', 'calendars', 'comes', 'march', 'may', 'one', 'four', 'months', 'days', 'april', 'always', 'begins', 'day', 'week', 'july', 'additionally', 'january', 'leap', 'years', 'april', 'always', 'ends', 'day', 'week', 'december', 'april', 'flowers', 'sweet', 'pea', 'daisy', 'birthstone', 'diamond', 'meaning', 'diamond', 'innocence', 'month', 'april', 'comes', 'march', 'may', 'making', 'fourth', 'month', 'year', 'also', 'comes', 'first', 'year', 'four', 'months', 'days', 'june', 'september', 'november', 'later', 'year', 'april', 'begins', 'day', 'week', 'july', 'every', 'year', 'day', 'week', 'january', 'leap', 'years', 'april', 'ends', 'day', 'week', 'december', 'every', 'year', 'last', 'days', 'exactly', 'weeks', 'days', 'apart', 'common', 'years', 'april', 'starts', 'day', 'week', 'october', 'previous', 'year', 'leap', 'years', 'may', 'previous', 'year', 'common', 'years', 'april', 'finishes', 'day', 'week', 'july', 'previous', 'year', 'leap', 'years', 'february', 'october', 'previous', 'year', 'common', 'years', 'immediately', 'common', 'years', 'april', 'starts', 'day', 'week', 'january', 'previous', 'year', 'leap', 'years', 'years', 'immediately', 'april', 'finishes', 'day', 'week', 'january', 'previous', 'year', 'years', 'immediately', 'common', 'years', 'april', 'starts', 'day', 'week', 'september', 'december', 'following', 'year', 'years', 'immediately', 'leap', 'years', 'june', 'following', 'year', 'years', 'immediately', 'common', 'years', 'april', 'finishes', 'day', 'week', 'september', 'following', 'year', 'years', 'immediately', 'leap', 'years', 'march', 'june', 'following', 'year', 'april', 'spring', 'month', 'northern', 'hemisphere', 'autumn', 'fall', 'month', 'southern', 'hemisphere', 'hemisphere', 'seasonal', 'equivalent', 'october', 'unclear', 'april', 'got', 'name', 'common', 'theory', 'comes', 'latin', 'word', 'aperire', 'meaning', 'open', 'referring', 'flowers', 'opening', 'spring', 'another', 'theory', 'name', 'come', 'aphrodite', 'greek', 'goddess', 'love', 'originally', 'second', 'month', 'old', 'roman', 'calendar', 'start', 'new', 'year', 'put', 'january', 'quite', 'festivals', 'held', 'month', 'many', 'southeast', 'asian', 'cultures', 'new', 'year', 'celebrated', 'month', 'including', 'songkran', 'western', 'christianity', 'easter', 'celebrated', 'sunday', 'march', 'april', 'orthodox', 'christianity', 'fall', 'april', 'may', 'end', 'month', 'central', 'northern', 'european', 'cultures', 'celebrate', 'walpurgis', 'night', 'april', 'marking', 'transition', 'winter', 'summer', 'april', 'poetry', 'poets', 'use', 'april', 'mean', 'end', 'winter', 'example', 'april', 'showers', 'bring', 'may', 'flowers', 'events', 'april', 'fixed', 'events', 'april', 'april', 'fools', 'day', 'april', 'islamic', 'republic', 'day', 'iran', 'april', 'international', 'children', 'book', 'day', 'april', 'thai', 'heritage', 'conservation', 'day', 'april', 'world', 'autism', 'awareness', 'day', 'april', 'malvinas', 'day', 'argentina', 'april', 'independence', 'day', 'senegal', 'april', 'international', 'day', 'landmine', 'awareness', 'assistance', 'april', 'peace', 'day', 'angola', 'april', 'end', 'tax', 'year', 'united', 'kingdom', 'april', 'tartan', 'day', 'canada', 'united', 'states', 'april', 'chakri', 'day', 'thailand', 'april', 'day', 'maternity', 'beauty', 'armenia', 'april', 'genocide', 'memorial', 'day', 'rwanda', 'april', 'world', 'health', 'day', 'april', 'women', 'day', 'mozambique', 'april', 'buddha', 'birthday', 'buddhism', 'april', 'martyrs', 'day', 'tunisia', 'april', 'day', 'national', 'unity', 'georgia', 'april', 'day', 'finnish', 'language', 'april', 'cosmonauts', 'day', 'russia', 'marking', 'day', 'yuri', 'gagarin', 'space', 'flight', 'april', 'songkan', 'laos', 'local', 'new', 'year', 'celebration', 'april', 'cambodian', 'new', 'year', 'april', 'thomas', 'jefferson', 'birthday', ...

# %%
cv = CountVectorizer(inputCol="filtered", outputCol="features", minDF=2.0).fit(removed_df)

lda_count = cv.transform(removed_df).drop('filtered')
lda_count.head()
# Out:
# 23/04/29 18:19:00 WARN TaskSetManager: Stage 4 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# 23/04/29 18:19:10 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 23/04/29 18:19:10 WARN TaskSetManager: Stage 8 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# Row(id='1', title='April', url='https://simple.wikipedia.org/wiki/April', features=SparseVector(221737, {0: 5.0, 1: 1.0, 2: 7.0, 3: 3.0, 4: 17.0, 5: 1.0, 6: 10.0, 7: 3.0, 8: 13.0, 9: 8.0, 12: 3.0, 13: 1.0, 14: 1.0, 17: 13.0, 18: 2.0, 19: 1.0, 22: 1.0, 25: 10.0, 26: 6.0, 27: 1.0, 32: 7.0, 34: 1.0, 35: 4.0, 37: 4.0, 38: 5.0, 40: 1.0, 41: 1.0, 42: 20.0, 44: 7.0, 46: 3.0, 49: 4.0, 50: 5.0, 55: 25.0, 56: 1.0, 59: 1.0, 60: 6.0, 61: 13.0, 62: 1.0, 65: 1.0, 66: 1.0, 67: 4.0, 71: 3.0, 72: 3.0, 76: 3.0, 77: 5.0, 78: 208.0, 81: 1.0, 82: 3.0, 85: 3.0, 86: 1.0, 90: 1.0, 93: 2.0, 94: 2.0, 96: 1.0, 97: 1.0, 103: 2.0, 106: 1.0, 109: 96.0, 111: 10.0, 117: 5.0, 120: 1.0, 123: 1.0, 126: 2.0, 129: 2.0, 140: 1.0, 142: 5.0, 147: 4.0, 152: 3.0, 153: 5.0, 154: 1.0, 155: 1.0, 156: 1.0, 158: 3.0, 159: 2.0, 160: 1.0, 161: 2.0, 162: 1.0, 170: 1.0, 175: 4.0, 176: 2.0, 181: 5.0, 183: 2.0, 184: 4.0, 186: 2.0, 187: 2.0, 188: 1.0, 192: 1.0, 194: 1.0, 198: 1.0, 199: 1.0, 200: 4.0, 203: 1.0, 204: 1.0, 205: 2.0, 206: 3.0, 207: 1.0, 210: 1.0, 214: 1.0, 215: 2.0, 218: 1.0, 223: 2.0, 228: 1.0, 240: 1.0, 243: 2.0, 244: 1.0, 245: 1.0, 246: 2.0, 248: 1.0, 249: 1.0, 250: 2.0, 251: 1.0, 252: 1.0, 253: 2.0, 255: 2.0, 258: 1.0, 259: 4.0, 262: 3.0, 265: 1.0, 270: 4.0, 273: 1.0, 274: 1.0, 277: 1.0, 280: 1.0, 282: 5.0, 289: 4.0, 290: 2.0, 293: 7.0, 294: 2.0, 295: 2.0, 296: 1.0, 300: 4.0, 301: 1.0, 303: 3.0, 307: 1.0, 316: 1.0, 324: 1.0, 331: 1.0, 333: 2.0, 334: 1.0, 336: 5.0, 337: 1.0, 341: 1.0, 347: 5.0, 348: 1.0, 349: 1.0, 351: 6.0, 357: 3.0, 358: 1.0, 359: 1.0, 360: 3.0, 364: 4.0, 365: 1.0, 366: 1.0, 368: 2.0, 370: 1.0, 371: 1.0, 374: 1.0, 379: 1.0, 384: 1.0, 392: 2.0, 393: 5.0, 395: 1.0, 396: 1.0, 397: 1.0, 398: 1.0, 399: 2.0, 411: 1.0, 413: 1.0, 417: 2.0, 418: 2.0, 422: 2.0, 425: 1.0, 426: 1.0, 431: 1.0, 443: 2.0, 445: 3.0, 449: 1.0, 450: 1.0, 453: 2.0, 454: 1.0, 462: 2.0, 466: 1.0, 468: 1.0, 473: 1.0, 477: 1.0, 480: 3.0, 481: 1.0, 490: 1.0, 497: 1.0, 500: 2.0, 506: 4.0, 514: 2.0, 515: 1.0, 522: 1.0, 525: 3.0, 527: 1.0, 535: 6.0, 536: 1.0, 539: 2.0, 549: 1.0, 550: 2.0, 551: 1.0, 553: 1.0, 555: 2.0, 560: 1.0, 561: 1.0, 564: 2.0, 572: 1.0, 573: 1.0, 574: 4.0, 576: 1.0, 579: 1.0, 584: 1.0, 591: 1.0, 601: 1.0, 603: 1.0, 604: 2.0, 605: 5.0, 624: 13.0, 628: 2.0, 635: 1.0, 643: 2.0, 645: 1.0, 646: 1.0, 654: 4.0, 659: 3.0, 663: 2.0, 665: 5.0, 666: 1.0, 676: 1.0, 684: 2.0, 688: 2.0, 689: 12.0, 691: 2.0, 700: 2.0, 702: 1.0, 713: 1.0, 723: 2.0, 726: 1.0, 727: 2.0, 736: 2.0, 740: 2.0, 744: 1.0, 748: 1.0, 752: 1.0, 755: 1.0, 762: 3.0, 763: 1.0, 764: 1.0, 782: 1.0, 785: 3.0, 788: 5.0, 793: 1.0, 798: 1.0, 799: 2.0, 811: 1.0, 815: 2.0, 824: 2.0, 829: 2.0, 831: 9.0, 854: 1.0, 857: 2.0, 865: 8.0, 870: 1.0, 871: 1.0, 886: 4.0, 889: 1.0, 903: 1.0, 906: 3.0, 911: 2.0, 912: 1.0, 916: 1.0, 919: 1.0, 930: 1.0, 940: 2.0, 941: 1.0, 950: 1.0, 958: 2.0, 967: 1.0, 969: 1.0, 973: 1.0, 986: 1.0, 987: 3.0, 990: 1.0, 992: 2.0, 993: 1.0, 999: 1.0, 1012: 1.0, 1022: 2.0, 1067: 2.0, 1070: 1.0, 1073: 1.0, 1077: 1.0, 1088: 2.0, 1090: 1.0, 1094: 1.0, 1117: 1.0, 1145: 1.0, 1159: 1.0, 1167: 1.0, 1169: 1.0, 1171: 1.0, 1180: 15.0, 1186: 1.0, 1200: 1.0, 1202: 1.0, 1203: 1.0, 1231: 1.0, 1268: 1.0, 1293: 2.0, 1305: 1.0, 1309: 1.0, 1315: 5.0, 1333: 3.0, 1360: 1.0, 1362: 4.0, 1365: 1.0, 1392: 1.0, 1394: 4.0, 1395: 1.0, 1403: 2.0, 1413: 1.0, 1422: 2.0, 1426: 2.0, 1441: 1.0, 1448: 1.0, 1449: 4.0, 1453: 1.0, 1455: 1.0, 1462: 1.0, 1472: 1.0, 1476: 2.0, 1494: 1.0, 1496: 3.0, 1502: 1.0, 1509: 1.0, 1512: 2.0, 1526: 1.0, 1531: 1.0, 1545: 1.0, 1554: 1.0, 1582: 1.0, 1584: 2.0, 1603: 3.0, 1609: 6.0, 1615: 4.0, 1620: 2.0, 1629: 1.0, 1633: 2.0, 1637: 1.0, 1656: 1.0, 1665: 1.0, 1669: 1.0, 1670: 2.0, 1673: 1.0, 1679: 1.0, 1684: 1.0, 1697: 1.0, 1719: 1.0, 1734: 1.0, 1760: 1.0, 1808: 1.0, 1836: 1.0, 1847: 1.0, 1869: 3.0, 1870: 2.0, 1871: 1.0, 1875: 1.0, 1876: 1.0, 1890: 2.0, 1921: 2.0, 1928: 1.0, 1940: 1.0, 1968: 1.0, 2011: 1.0, 2020: 1.0, 2033: 1.0, 2047: 1.0, 2077: 1.0, 2104: 1.0, 2118: 4.0, 2119: 1.0, 2139: 4.0, 2150: 1.0, 2155: 1. ...

# %%
from pyspark.ml.clustering import LDA

# create LDA with K topics

start = time.time()
lda = LDA(k=K, seed=1, optimizer="em", maxIter=MAX_ITER, checkpointInterval=CHECKPOINT)
model = lda.fit(lda_count)
end = time.time()

print(f"Time elapsed: {end-start:.2f} seconds")
# Out:
# 23/04/29 18:28:53 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 23/04/29 18:28:53 WARN TaskSetManager: Stage 46 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# 23/04/29 18:28:53 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 23/04/29 18:28:53 WARN TaskSetManager: Stage 47 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# 23/04/29 18:28:53 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 23/04/29 18:28:53 WARN DAGScheduler: Broadcasting large task binary with size 2.2 MiB
# 23/04/29 18:28:54 WARN TaskSetManager: Stage 48 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# 23/04/29 18:28:57 WARN TaskSetManager: Stage 49 contains a task of very large size (11931 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 15700:====================================================>(63 + 1) / 64]]
# Time elapsed: 895.63 seconds

# %%
topicIndices = model.describeTopics(maxTermsPerTopic = 5)
vocabList = cv.vocabulary

for row in topicIndices.collect():
    print(f"Topic {row.topic + 1}: ")
    for topic, weight in zip(row.termIndices, row.termWeights):
        print(f"{vocabList[topic]} {weight:.2E}")
    print()
# Out:
# Topic 1:
# league 6.48E-02
# football 6.11E-02
# rowspan 5.91E-02
# club 4.23E-02
# colspan 3.72E-02
#
# Topic 2:
# may 3.65E-01
# death 9.33E-02
# home 5.77E-02
# hospital 3.31E-02
# natural 3.24E-02
#
# Topic 3:
# countries 3.16E-02
# empire 2.80E-02
# history 1.25E-02
# europe 1.24E-02
# independence 1.20E-02
#
# Topic 4:
# websites 5.12E-01
# official 1.61E-01
# website 1.39E-01
# site 4.33E-02
# page 2.72E-02
#
# Topic 5:
# movies 1.86E-01
# movie 7.49E-02
# directed 4.30E-02
# drama 4.09E-02
# comedy 3.18E-02
#
# Topic 6:
# john 8.11E-02
# james 4.09E-02
# george 3.89E-02
# william 3.28E-02
# robert 2.88E-02
#
# Topic 7:
# business 1.64E-02
# development 1.29E-02
# bank 1.28E-02
# public 1.08E-02
# services 9.88E-03
#
# Topic 8:
# best 1.01E-01
# award 8.75E-02
# awards 4.72E-02
# won 3.73E-02
# academy 2.92E-02
#
# Topic 9:
# german 8.59E-02
# germany 7.74E-02
# austria 1.91E-02
# austrian 1.85E-02
# bavaria 1.77E-02
#
# Topic 10:
# art 4.55E-02
# ancient 3.34E-02
# bc 2.87E-02
# greek 2.39E-02
# artists 1.59E-02
#
# Topic 11:
# english 1.40E-01
# french 1.15E-01
# paris 4.06E-02
# de 3.08E-02
# l 2.98E-02
#
# Topic 12:
# also 5.26E-01
# known 2.71E-01
# well 8.30E-02
# first 4.28E-02
# better 1.51E-02
#
# Topic 13:
# royal 4.09E-02
# present 3.38E-02
# queen 3.35E-02
# prince 3.14E-02
# louis 2.81E-02
#
# Topic 14:
# church 5.61E-02
# christian 2.85E-02
# catholic 2.75E-02
# roman 2.69E-02
# god 2.46E-02
#
# Topic 15:
# association 5.46E-02
# green 4.45E-02
# basketball 4.28E-02
# oklahoma 3.99E-02
# minnesota 3.49E-02
#
# Topic 16:
# short 5.66E-02
# story 5.46E-02
# fiction 3.67E-02
# science 3.60E-02
# young 3.48E-02
#
# Topic 17:
# became 6.30E-02
# later 4.77E-02
# first 4.39E-02
# started 3.16E-02
# made 3.10E-02
#
# Topic 18:
# references 8.54E-01
# frog 2.56E-02
# frogs 1.26E-02
# tree 1.09E-02
# lives 1.08E-02
#
# Topic 19:
# london 5.90E-02
# line 3.80E-02
# station 3.49E-02
# west 2.89E-02
# england 2.71E-02
#
# Topic 20:
# air 6.63E-02
# airport 3.70E-02
# international 3.36E-02
# aircraft 2.77E-02
# flight 2.70E-02
#
# Topic 21:
# light 2.18E-02
# earth 1.86E-02
# sun 1.41E-02
# energy 1.12E-02
# system 8.86E-03
#
# Topic 22:
# space 3.15E-02
# fire 2.75E-02
# ship 1.96E-02
# nuclear 1.74E-02
# events 1.52E-02
#
# Topic 23:
# year 1.17E-01
# years 9.39E-02
# time 8.65E-02
# day 7.13E-02
# old 5.16E-02
#
# Topic 24:
# number 6.57E-02
# numbers 2.01E-02
# x 1.90E-02
# set 1.29E-02
# point 1.18E-02
#
# Topic 25:
# california 1.23E-01
# los 5.54E-02
# san 5.33E-02
# angeles 5.03E-02
# louisiana 2.46E-02
#
# Topic 26:
# united 3.04E-01
# states 2.69E-01
# illinois 3.36E-02
# chicago 3.31E-02
# washington 3.26E-02
#
# Topic 27:
# species 2.61E-02
# animals 1.35E-02
# found 1.11E-02
# birds 9.20E-03
# fish 8.72E-03
#
# Topic 28:
# life 1.07E-01
# children 7.04E-02
# married 4.81E-02
# father 4.27E-02
# worked 3.82E-02
#
# Topic 29:
# music 6.86E-02
# opera 1.91E-02
# composer 1.29E-02
# composers 1.27E-02
# orchestra 1.26E-02
#
# Topic 30:
# c 9.97E-02
# e 7.40E-02
# n 5.94E-02
# r 5.40E-02
# d 4.64E-02
#
# Topic 31:
# body 1.63E-02
# blood 1.55E-02
# cause 1.07E-02
# person 1.06E-02
# medical 1.06E-02
#
# Topic 32:
# red 2.35E-02
# white 2.20E-02
# food 2.18E-02
# blue 1.70E-02
# color 1.54E-02
#
# Topic 33:
# north 2.63E-01
# america 1.05E-01
# dutch 5.16E-02
# carolina 5.06E-02
# netherlands 4.09E-02
#
# Topic 34:
# radio 4.61E-02
# com 4.10E-02
# news 3.38E-02
# media 2.94E-02
# channel 2.57E-02
#
# Topic 35:
# prize 2.04E-02
# scientists 1.92E-02
# nobel 1.50E-02
# cell 1.26E-02
# study 1.11E-02
#
# Topic 36:
# war 8.75E-02
# army 3.43E-02
# military 3.33E-02
# battle 1.95E-02
# ii 1.56E-02
#
# Topic 37:
# china 7.92E-02
# chinese 6.39E-02
# kong 2.16E-02
# li 2.03E-02
# hong 1.97E-02
#
# Topic 38:
# m 1.76E-01
# center 9.34E-02
# p 7.64E-02
# style 5.48E-02
# left 5.19E-02
#
# Topic 39:
# call 2.75E-02
# mobile 2.41E-02
# fox 2.29E-02
# image 1.95E-02
# worldwide 1.79E-02
#
# Topic 40:
# born 3.60E-02
# actor 8.93E-03
# player 8.46E-03
# joe 8.12E-03
# singer 8.01E-03
#
# Topic 41:
# name 2.25E-01
# family 1.34E-01
# named 1.16E-01
# given 4.47E-02
# paul 3.09E-02
#
# Topic 42:
# person 2.56E-02
# good 1.53E-02
# way 1.28E-02
# say 1.28E-02
# things 1.28E-02
#
# Topic 43:
# establishments 1.67E-01
# company 6.91E-02
# europe 6.86E-02
# russian 5.79E-02
# founded 5.26E-02
#
# Topic 44:
# de 6.13E-02
# o 3.80E-02
# spanish 3.74E-02
# n 3.57E-02
# la 3.02E-02
#
# Topic 45:
# sweden 6.65E-02
# swedish 4.55E-02
# v 3.98E-02
# argentina 2.30E-02
# chile 2.17E-02
#
# Topic 46:
# union 8.02E-02
# republic 7.18E-02
# soviet 5.66E-02
# star 5.32E-02
# jewish 4.50E-02
#
# Topic 47:
# love 9.87E-03
# god 9.06E-03
# tells 8.25E-03
# mythology 7.78E-03
# goddess 6.76E-03
#
# Topic 48:
# japan 1.17E-01
# japanese 8.83E-02
# prefecture 3.23E-02
# tokyo 2.35E-02
# emperor 1.44E-02
#
# Topic 49:
# actors 1.71E-01
# movie 9.40E-02
# television 6.59E-02
# actor 4.11E-02
# born 4.05E-02
#
# Topic 50:
# american 5.22E-01
# cancer 5.81E-02
# texas 5.19E-02
# disease 3.50E-02
# heart 2.71E-02
#
# Topic 51:
# south 1.13E-01
# island 7.65E-02
# africa 4.03E-02
# islands 3.94E-02
# african 3.83E-02
#
# Topic 52:
# game 9.08E-02
# games 6.56E-02
# video 5.29E-02
# player 2.04E-02
# released 1.65E-02
#
# Topic 53:
# country 5.27E-02
# population 3.28E-02
# area 3.20E-02
# community 3.06E-02
# largest 2.52E-02
#
# Topic 54:
# river 9.53E-02
# capital 3.49E-02
# province 3.48E-02
# km 2.88E-02
# region 2.77E-02
#
# Topic 55:
# part 2.76E-01
# great 8.19E-02
# notes 3.83E-02
# britain 2.69E-02
# cross 2.51E-02
#
# Topic 56:
# national 2.17E-01
# park 8.60E-02
# museum 3.24E-02
# scottish 2.78E-02
# scotland 2.58E-02
#
# Topic 57:
# said 3.57E-02
# get 3.03E-02
# make 2.86E-02
# go 2.58E-02
# take 2.05E-02
#
# Topic 58:
# world 1.94E-01
# related 1.29E-01
# group 1.28E-01
# history 1.13E-01
# since 1.05E-01
#
# Topic 59:
# law 4.17E-02
# court 2.98E-02
# rights 1.75E-02
# act 1.69E-02
# state 1.65E-02
#
# Topic 60:
# italian 8.33E-02
# italy 6.25E-02
# di 2.03E-02
# rome 1.29E-02
# milan 1.05E-02
#
# Topic 61:
# water 3.16E-02
# chemical 1.79E-02
# used 1.53E-02
# made 1.25E-02
# gas 1.10E-02
#
# Topic 62:
# county 1.78E-01
# state 7.56E-02
# cities 5.75E-02
# u 5.13E-02
# census 4.66E-02
#
# Topic 63:
# first 1.80E-01
# second 1.07E-01
# third 5.41E-02
# race 3.15E-02
# fourth 2.06E-02
#
# Topic 64:
# france 7.75E-02
# department 6.34E-02
# communes 4.72E-02
# commune 4.55E-02
# de 3.94E-02
#
# Topic 65:
# one 2.71E-01
# two 1.78E-01
# three 9.59E-02
# four 6.06E-02
# five 4.01E-02
#
# Topic 66:
# university 1.27E-01
# school 4.29E-02
# college 3.94E-02
# education 2.69E-02
# students 1.96E-02
#
# Topic 67:
# town 1.90E-01
# towns 8.03E-02
# village 7.77E-02
# villages 4.19E-02
# polish 3.57E-02
#
# Topic 68:
# politicians 6.05E-02
# party 4.67E-02
# us 3.70E-02
# election 3.39E-02
# democratic 3.10E-02
#
# Topic 69:
# b 6.12E-02
# d 4.96E-02
# american 4.10E-02
# actor 1.10E-02
# politician 1.06E-02
#
# Topic 70:
# th 3.29E-01
# century 1.84E-01
# st 1.32E-01
# place 9.60E-02
# nd 2.78E-02
#
# Topic 71:
# deaths 2.26E-01
# births 2.21E-01
# born 1.95E-01
# died 1.44E-01
# age 7.98E-02
#
# Topic 72:
# series 1.22E-01
# television 7.94E-02
# show 5.98E-02
# season 2.47E-02
# episode 2.37E-02
#
# Topic 73:
# new 3.78E-01
# city 2.36E-01
# york 1.39E-01
# jersey 2.90E-02
# major 2.21E-02
#
# Topic 74:
# american 3.09E-02
# politician 2.62E-02
# cancer 1.18E-02
# heart 9.49E-03
# actor 7.90E-03
#
# Topic 75:
# january 1.15E-01
# march 1.02E-01
# june 9.39E-02
# april 9.34E-02
# october 9.28E-02
#
# Topic 76:
# political 5.96E-02
# party 4.41E-02
# social 3.15E-02
# movement 2.93E-02
# parties 1.56E-02
#
# Topic 77:
# players 5.51E-02
# hockey 4.67E-02
# canadian 4.54E-02
# canada 4.20E-02
# ice 3.46E-02
#
# Topic 78:
# language 7.29E-02
# word 4.61E-02
# languages 3.44E-02
# words 2.82E-02
# english 2.51E-02
#
# Topic 79:
# high 1.31E-01
# school 8.89E-02
# northern 5.71E-02
# ireland 4.61E-02
# irish 3.65E-02
#
# Topic 80:
# president 9.11E-02
# minister 5.94E-02
# prime 4.70E-02
# government 3.53E-02
# general 3.19E-02
#
# Topic 81:
# district 1.11E-01
# municipality 1.04E-01
# former 6.85E-02
# municipalities 6.37E-02
# switzerland 4.71E-02
#
# Topic 82:
# women 8.13E-02
# men 4.67E-02
# man 4.51E-02
# woman 3.78E-02
# female 3.39E-02
#
# Topic 83:
# championship 3.21E-02
# wrestling 2.44E-02
# match 2.23E-02
# world 2.00E-02
# professional 1.97E-02
#
# Topic 84:
# k 6.32E-02
# mount 2.29E-02
# norway 1.81E-02
# rock 1.79E-02
# active 1.65E-02
#
# Topic 85:
# characters 1.64E-02
# animated 1.59E-02
# disney 1.46E-02
# character 1.41E-02
# fictional 9.54E-03
#
# Topic 86:
# tropical 3.11E-02
# storm 2.90E-02
# hurricane 2.76E-02
# atlantic 2.01E-02
# pacific 1.32E-02
#
# Topic 87:
# india 6.14E-02
# indian 4.72E-02
# pakistan 3.30E-02
# district 1.70E-02
# bangladesh 1.20E-02
#
# Topic 88:
# police 3.00E-02
# killed 1.73E-02
# prison 1.56E-02
# murder 1.37E-02
# camp 1.15E-02
#
# Topic 89:
# british 1.60E-01
# australia 7.95E-02
# australian 5.85E-02
# order 3.11E-02
# wales 2.83E-02
#
# Topic 90:
# built 3.35E-02
# building 2.83E-02
# buildings 2.42E-02
# land 1.69E-02
# castle 1.28E-02
#
# Topic 91:
# power 3.34E-02
# car 3.13E-02
# class 2.67E-02
# electric 1.70E-02
# model 1.58E-02
#
# Topic 92:
# summer 4.87E-02
# sports 3.42E-02
# won 3.40E-02
# gold 3.39E-02
# olympics 3.19E-02
#
# Topic 93:
# used 7.42E-02
# many 5.17E-02
# called 5.02E-02
# different 4.26E-02
# often 3.62E-02
#
# Topic 94:
# album 3.69E-02
# song 3.23E-02
# band 2.73E-02
# music 2.57E-02
# released 2.45E-02
#
# Topic 95:
# member 1.03E-01
# kingdom 7.23E-02
# members 6.89E-02
# house 5.30E-02
# council 4.56E-02
#
# Topic 96:
# people 7.49E-01
# living 2.04E-01
# black 2.14E-02
# lived 3.08E-03
# live 1.43E-03
#
# Topic 97:
# king 8.33E-02
# ii 4.15E-02
# england 3.38E-02
# iii 2.21E-02
# roman 1.96E-02
#
# Topic 98:
# side 1.79E-02
# hand 1.14E-02
# made 1.12E-02
# ball 1.12E-02
# move 7.79E-03
#
# Topic 99:
# book 5.14E-02
# books 4.44E-02
# writers 3.89E-02
# published 3.37E-02
# wrote 2.85E-02
#
# Topic 100:
# computer 2.27E-02
# system 1.46E-02
# data 1.37E-02
# information 1.22E-02
# windows 1.17E-02

# %%
model.write().overwrite().save('/scratch/tmv7269/lda')
